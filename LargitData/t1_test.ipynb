# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
res = requests.get("https://list.tmall.com/search_product.htm?q=%B6%E0%D1%F9%CE%DD%B1%A3%CE%C2%B1%AD&type=p&vmarket=&spm=813.0.a2227oh.d100&xl=duoyang_2&from=..pc_1_suggest")

# %%
print (res.text)
# Out:
# <!DOCTYPE HTML>
# <html>
#
#
#
#
#
#
# <head><meta charset="gbk" /><meta name="spm-id" content="a220m.1000858"/><meta name="renderer" content="webkit"><meta name="description" content="多样屋保温杯-TAYOHYA/多样屋,品类齐全，欢迎选购！"/><meta name="viewport" content="width=device-width" /><link rel="dns-prefetch" href="//g.alicdn.com"/><link rel="dns-prefetch" href="//assets.alicdn.com"/><link rel="dns-prefetch" href="//img.alicdn.com"/><link rel="dns-prefetch" href="//smc.tmall.com"/><link rel="dns-prefetch" href="//www.tmall.com"/><link rel="dns-prefetch" href="//bar.tmall.com"/><link rel="dns-prefetch" href="//pcookie.tmall.com"/><link rel="dns-prefetch" href="//log.mmstat.com"/><link rel="dns-prefetch" href="//ac.mmstat.com"/><link rel="dns-prefetch" href="//ac.atpanel.com"/><link rel="dns-prefetch" href="//amos.alicdn.com"/>  <title>多样屋保温杯-TAYOHYA/多样屋-天猫Tmall.com-理想生活上天猫</title>
#   <link rel="shortcut icon" href="//img.alicdn.com/tfs/TB1XlF3RpXXXXc6XXXXXXXXXXXX-16-16.png" type="image/x-icon"/>
# ...

# %%
html_sample =' \
<html> \
  <body> \
    <h1 id="title"> Hello World</h1> \
    <a href="#" class="link">This is link1</a> \
    <a href="# link2" class="link">This is link2</a> \
  </body> \
</html>'

# %%
soup = BeautifulSoup(html_sample)

# %%
soup.text
# Out:
# '   Hello World This is link1 This is link2  '

# %%
soup.contents
# Out:
# [<html> <body> <h1 id="title"> Hello World</h1> <a class="link" href="#">This is link1</a> <a class="link" href="# link2">This is link2</a> </body> </html>]

# %%
soup.select('a')[1]
# Out:
# <a class="link" href="# link2">This is link2</a>

# %%
soup = BeautifulSoup(res.text)

# %%
for item in soup.select('.product'):
    print (item.select('title'))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
payload = {
'StartStationName':  '台北站',
'EndStationName':  '桃園站',
'SearchType': 'S',
'StartStation': '977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation': 'fbd828d8-b1da-4b06-a3bd-680cdca4d2cd',
'DepartueSearchDate': '2019/12/16',
'DepartueSearchTime': '11:30',
'DepartueTrainCode': '',
'DestinationSearchDate': '',
'DestinationSearchTime': '',
'DiscountType':'',
}

# %%
res = requests.post("http://www.thsrc.com.tw/tw/TimeTable/Search", data=payload )

# %%
print(res.text)
# Out:
# {"success":true,"data":{"DepartureTable":{"Title":{"TitleSplit1":"台北站","TitleSplit2":"桃園站&nbsp;&nbsp;2019/12/16(一)&nbsp;&nbsp;11:30"},"TrainItem":[{"TrainNumber":"0803","DepartureTime":"06:26","DestinationTime":"06:47","Duration":"00:21","NonReservedCar":"4","Discount":[{"Id":"68d9fc7b-7330-44c2-962a-74bc47d2ee8a","Name":"大學生","Value":"75折","Color":"#e45916"}],"Note":"","Sequence":0,"StationInfo":[{"StationNo":"01","StationName":"南港站","DepartureTime":"06:15","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北站","DepartureTime":"06:26","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋站","DepartureTime":"06:34","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園站","DepartureTime":"06:49","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹站","DepartureTime":"07:02","Show":true,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗站","DepartureTime":"07:13","Show":true,"ColorClass":"sky_blue"},{"Stat
# ...
